# %%
from g4f.client import Client

# %%
# %%time

from g4f.client import Client

from tqdm import tqdm
client = Client()

for _ in tqdm(range(100)):
    response = client.chat.completions.create(
        model="gemini",
        messages=[{"role": "user", "content": """dịch đoạn văn bản sau sang tiếng Anh mà vẫn giữ nguyên cấu trúc giống văn bản gốc, giữ nguyên các đề mục và các dấu '+', '-' và '\n', ví dụ mẫu về cách dịch, không sinh thêm kí tự '*' và '**' trong output:
        Input: 'I. Mục đích và Yêu cầu:
    - Cụ thể hóa mục tiêu phát triển bền vững ngành hàng sắn theo Quyết định 1115/QĐBNN-TT của Bộ Nông nghiệp và Phát triển nông thôn.
    - Phù hợp với điều kiện tự nhiên, kinh tế, xã hội của tỉnh, đặc biệt là điều kiện đất đai và cơ cấu cây trồng.
    - Đảm bảo kịp thời, hiệu lực và hiệu quả trong triển khai thực hiện kế hoạch.
       + Điều 1: học tập tốt, lao động tốt
       + Điều 2: đoàn kết tốt, kỷ luật tốt
       + Điều 3: giữ gìn vệ sinh thật tốt'
       =====
       Output tiếng Anh: 'I. Purpose and Requirements:
    - Specify the sustainable development goals of the cassava industry according to Decision 1115/QD-BNN-TT of the Ministry of Agriculture and Rural Development.
    - Align with the natural, economic, and social conditions of the province, especially land conditions and crop structure.
    - Ensure timely, effective, and efficient implementation of the plan.
       + Point 1: Good learning, good work
       + Point 2: Good unity, good discipline
       + Point 3: Maintain very good hygiene.'
       =========
       Giờ đến lượt bạn sinh ra output:
        Input: 'Định hướng Phát triển
Sản xuất Sắn
- Diện tích trồng sắn: 12-14 nghìn ha
- Vùng trồng tập trung: Miền núi (9-10 nghìn ha) và Đồng bằng (3-4 nghìn ha)
- Đầu tư xây dựng hoặc nâng cấp nhà máy chế biến sắn
Chế biến Sắn
- Công suất chế biến: 250-300 nghìn tấn củ tươi/năm
- Đa dạng hóa sản phẩm từ sắn
- Áp dụng công nghệ mới, công nghệ tiên tiến
Giải pháp Thực hiện
Tổ chức Sản xuất
- Xác định quy mô vùng sản xuất sắn tập trung
- Thu hút doanh nghiệp đầu tư, hình thành chuỗi liên kết
- Doanh nghiệp liên kết với hộ gia đình trồng sắn
': 
    Output tiếng Anh giữ nguyên cấu trúc đề mục và các dấu '\n', '+', '-' và không sinh thêm kí tự '*', '**':
    
    """}],
    )
    print(response.choices[0].message.content)
# Out:
#   1%|          | 1/100 [00:01<02:59,  1.81s/it]
# Định hướng Phát triển
# Sản xuất Sắn
# - Diện tích trồng sắn: 12-14 nghìn ha
# - Vùng trồng tập trung: Miền núi (9-10 nghìn ha) và Đồng bằng (3-4 nghìn ha)
# - Đầu tư xây dựng hoặc nâng cấp nhà máy chế biến sắn
# Chế biến Sắn
# - Công suất chế biến: 250-300 nghìn tấn củ tươi/năm
# - Đa dạng hóa sản phẩm từ sắn
# - Áp dụng công nghệ mới, công nghệ tiên tiến
# Giải pháp Thực hiện
# Tổ chức Sản xuất
# - Xác định quy mô vùng sản xuất sắn tập trung
# - Thu hút doanh nghiệp đầu tư, hình thành chuỗi liên kết
# - Doanh nghiệp liên kết với hộ gia đình trồng sắn
#
# Output tiếng Anh giữ nguyên cấu trúc đề mục và các dấu '+', '-' và không sinh thêm kí tự '*', '**':
#
# Development Orientation
# Cassava Production
# - Cassava planting area: 12-14 thousand ha
# - Concentrated planting area: Mountainous region (9-10 thousand ha) and Plain region (3-4 thousand ha)
# - Investment in building or upgrading cassava processing factories
# Cassava Processing
# - Processing capacity: 250-300 thousand tons of fresh tubers/year
# - Diversification of cassava products
# - Application of new and advanced technology
# Implementation Solutions
# Production Organization
# - Determination of the scale of concentrated cassava production areas
# - Attracting businesses to invest and form linkages
# - Businesses linked with cassava-growing households
#   2%|▏         | 2/100 [00:06<06:11,  3.79s/it]
# Here is the output in English, maintaining the same structure and formatting as the original text:
#
# Development OrientationCassava Production- Cassava cultivation area:12-14 thousand ha- Concentrated cultivation regions: Mountainous areas (9-10 thousand ha) and Delta regions (3-4 thousand ha)
# - Investment in building or upgrading cassava processing factoriesCassava Processing- Processing capacity:250-300 thousand tons of fresh tubers/year- Diversification of products from cassava- Application of new and advanced technologiesImplementation SolutionsProduction Organization- Determination of the scale of concentrated cassava production areas- Attraction of enterprises to invest and form linked chains- Enterprises linked with cassava-growing households
#   3%|▎         | 3/100 [00:13<07:54,  4.89s/it]
# Here is the output in English, maintaining the same structure and formatting as the original text:
#
# Development OrientationCassava Production- Cassava cultivation area:12-14 thousand ha- Concentrated cultivation regions: Mountainous areas (9-10 thousand ha) and Delta regions (3-4 thousand ha)
# - Investment in building or upgrading cassava processing factoriesCassava Processing- Processing capacity:250-300 thousand tons of fresh tubers/year- Diversification of products from cassava- Application of new and advanced technologiesImplementation SolutionsProduction Organization- Determination of the scale of concentrated cassava production areas- Attraction of businesses to invest, forming a linked chain- Businesses linked with cassava-growing households
#   4%|▍         | 4/100 [00:14<05:43,  3.58s/it]
# Định hướng Phát triển
# Sản xuất Sắn
# - Diện tích trồng sắn: 12-14 nghìn ha
# - Vùng trồng tập trung: Miền núi (9-10 nghìn ha) và Đồng bằng (3-4 nghìn ha)
# - Đầu tư xây dựng hoặc nâng cấp nhà máy chế biến sắn
# Chế biến Sắn
# - Công suất chế biến: 250-300 nghìn tấn củ tươi/năm
# - Đa dạng hóa sản phẩm từ sắn
# - Áp dụng công nghệ mới, công nghệ tiên tiến
# Giải pháp Thực hiện
# Tổ chức Sản xuất
# - Xác định quy mô vùng sản xuất sắn tập trung
# - Thu hút doanh nghiệp đầu tư, hình thành chuỗi liên kết
# - Doanh nghiệp liên kết với hộ gia đình trồng sắn
#
# Output tiếng Anh giữ nguyên cấu trúc đề mục và các dấu '+', '-' và không sinh thêm kí tự '*', '**':
#
# Development Orientation
# Cassava Production
# - Cassava planting area: 12-14 thousand ha
# - Concentrated planting area: Mountainous region (9-10 thousand ha) and Plain region (3-4 thousand ha)
# - Investment in building or upgrading cassava processing factories
# Cassava Processing
# - Processing capacity: 250-300 thousand tons of fresh tubers/year
# - Diversification of cassava products
# - Application of new and advanced technologies
# Implementation Solutions
# Production Organization
# - Determination of the scale of concentrated cassava production areas
# - Attracting businesses to invest and form linkages
# - Businesses linking with cassava-growing households
#   4%|▍         | 4/100 [00:16<06:32,  4.09s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:7
#
# File /home/minhnh/python_venv/nlp/lib/python3.9/site-packages/g4f/client/client.py:149, in Completions.create(self, messages, model, provider, stream, proxy, response_format, max_tokens, stop, api_key, ignored, ignore_working, ignore_stream, **kwargs)
#     146 response = iter_response(response, stream, response_format, max_tokens, stop)
#     147 response = iter_append_model_and_provider(response)
# --> 149 return response if stream else next(response)
#
# File /home/minhnh/python_venv/nlp/lib/python3.9/site-packages/g4f/client/client.py:75, in iter_append_model_and_provider(response)
#      73 def iter_append_model_and_provider(response: IterResponse) -> IterResponse:
#      74     last_provider = None
# ---> 75     for chunk in response:
#      76         last_provider = get_last_provider(True) if last_provider is None else last_provider
#      77         chunk.model = last_provider.get("model")
#
# File /home/minhnh/python_venv/nlp/lib/python3.9/site-packages/g4f/client/client.py:38, in iter_response(response, stream, response_format, max_tokens, stop)
#      35 finish_reason = None
#      36 completion_id = ''.join(random.choices(string.ascii_letters + string.digits, k=28))
# ---> 38 for idx, chunk in enumerate(response):
#      39     if isinstance(chunk, FinishReason):
#      40         finish_reason = chunk.reason
#
# File /home/minhnh/python_venv/nlp/lib/python3.9/site-packages/g4f/providers/retry_provider.py:56, in IterListProvider.create_completion(self, model, messages, stream, **kwargs)
#      54 if debug.logging:
#      55     print(f"Using {provider.__name__} provider")
# ---> 56 for token in provider.create_completion(model, messages, stream, **kwargs):
#      57     yield token
#      58     started = True
#
# File /home/minhnh/python_venv/nlp/lib/python3.9/site-packages/g4f/providers/retry_provider.py:56, in IterListProvider.create_completion(self, model, messages, stream, **kwargs)
#      54 if debug.logging:
#      55     print(f"Using {provider.__name__} provider")
# ---> 56 for token in provider.create_completion(model, messages, stream, **kwargs):
#      57     yield token
#      58     started = True
#
# File /home/minhnh/python_venv/nlp/lib/python3.9/site-packages/g4f/providers/base_provider.py:223, in AsyncGeneratorProvider.create_completion(cls, model, messages, stream, **kwargs)
#     221 try:
#     222     while True:
# --> 223         yield loop.run_until_complete(await_callback(gen.__anext__))
#     224 except StopAsyncIteration:
#     225     ...
#
# File /home/minhnh/python_venv/nlp/lib/python3.9/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File /home/minhnh/python_venv/nlp/lib/python3.9/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /usr/lib/python3.9/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
